# %% [markdown]
# # RocketPy Simulation
# This notebook was generated using Rocket-Serializer, a RocketPy tool to convert simulation files to RocketPy simulations
# The notebook was generated using the following parameters file: `Simulation\parameters.json`

# %%
# %pip install rocketpy<=2.0
# Out:
# Note: you may need to restart the kernel to use updated packages.
# The system cannot find the file specified.

# %%
from rocketpy import (
    Environment,
    SolidMotor,
    Rocket,
    Flight,
    TrapezoidalFins,
    EllipticalFins,
    RailButtons,
    NoseCone,
    Tail,
    Parachute,
)
import datetime

# %% [markdown]
# ## Environment

# %%
env = Environment()
env.set_location(latitude=28.61, longitude=-80.6)
env.set_elevation(274.32)

# %% [markdown]
# Optionally, you can set the date and atmospheric model

# %%
tomorrow = datetime.date.today() + datetime.timedelta(days=1)
env.set_date((tomorrow.year, tomorrow.month, tomorrow.day, 12))
# env.set_atmospheric_model(type='Forecast', file='GFS')

# %%
env.all_info()
# Out:
# Gravity Details
#
# Acceleration of gravity at surface level:    9.7795 m/s²
# Acceleration of gravity at  80.000 km (ASL): 9.5379 m/s²
#
#
# Launch Site Details
#
# Launch Date: 2025-04-09 12:00:00 UTC
# Launch Site Latitude: 28.61000°
# Launch Site Longitude: -80.60000°
# Reference Datum: SIRGAS2000
# Launch Site UTM coordinates: 166021.44 W|E    0.00 N
# Launch Site UTM zone: 31N
# Launch Site Surface Elevation: 274.3 m
#
#
# Atmospheric Model Details
#
# Atmospheric Model Type: standard_atmosphere
# standard_atmosphere Maximum Height: 80.000 km
#
# Surface Atmospheric Conditions
#
# Surface Wind Speed: 0.00 m/s
# Surface Wind Direction: 0.00°
# Surface Wind Heading: 0.00°
# Surface Pressure: 981.10 hPa
# Surface Temperature: 286.37 K
# Surface Air Density: 1.193 kg/m³
# Surface Speed of Sound: 339.17 m/s
#
#
# Earth Model Details
#
# Earth Radius at Launch site: 6378.14 km
# Semi-major Axis: 6378.14 km
# Semi-minor Axis: 6356.75 km
# Flattening: 0.0034
#
#
#
# Gravity Model Plots
# Atmospheric Model Plots

# %% [markdown]
# ## Motor
# Currently, only Solid Motors are supported by Rocket-Serializer. If you want to use a Liquid/Hybrid motor, please use rocketpy directly.

# %%
motor = SolidMotor(
    thrust_source="thrust_source.csv",
    dry_mass=0,
    center_of_dry_mass_position=0,
    dry_inertia=[0, 0, 0],
    grains_center_of_mass_position=0,
    grain_number=1,
    grain_density=977.8358759240072,
    grain_outer_radius=0.0375,
    grain_initial_inner_radius=0.01875,
    grain_initial_height=0.6997000122070313,
    grain_separation=0,
    nozzle_radius=0.028124999999999997,
    nozzle_position=-0.34985000610351563,
    throat_radius=0.01875,
    reshape_thrust_curve=False,  # Not implemented in Rocket-Serializer
    interpolation_method="linear",
    coordinate_system_orientation="nozzle_to_combustion_chamber",
)

# %%
motor.all_info()
# Out:
# Nozzle Details
# Nozzle Radius: 0.028124999999999997 m
# Nozzle Throat Radius: 0.01875 m
#
# Grain Details
# Number of Grains: 1
# Grain Spacing: 0 m
# Grain Density: 977.8358759240072 kg/m3
# Grain Outer Radius: 0.0375 m
# Grain Inner Radius: 0.01875 m
# Grain Height: 0.6997000122070313 m
# Grain Volume: 0.002 m3
# Grain Mass: 2.267 kg
#
# Motor Details
# Total Burning Time: 2.754 s
# Total Propellant Mass: 2.267 kg
# Structural Mass Ratio: 0.000
# c:\Users\arthu\AppData\Local\Programs\Python\Python313\Lib\site-packages\rocketpy\mathutils\function.py:1904: RuntimeWarning: invalid value encountered in divide
#   vector_b.extend(3 * ((y[2:] - y[1:-1]) / h[1:] - (y[1:-1] - y[:-2]) / h[:-1]))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\arthu\AppData\Local\Programs\Python\Python313\Lib\site-packages\rocketpy\mathutils\function.py:3566, in funcify_method.<locals>.funcify_method_decorator.__get__(self, instance, owner)
#    3564 try:
#    3565     # If cache is ready, return it
# -> 3566     val = cache[self.attrname]
#    3567 except KeyError:
#    3568     # If cache is not ready, create it
#
# KeyError: 'exhaust_velocity'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 motor.all_info()
#
# File c:\Users\arthu\AppData\Local\Programs\Python\Python313\Lib\site-packages\rocketpy\motors\motor.py:1162, in Motor.all_info(self)
#    1160 def all_info(self):
#    1161     """Prints out all data and graphs available about the Motor."""
# -> 1162     self.prints.all()
#    1163     self.plots.all()
#
# File c:\Users\arthu\AppData\Local\Programs\Python\Python313\Lib\site-packages\rocketpy\prints\solid_motor_prints.py:87, in _SolidMotorPrints.all(self)
#      85 self.nozzle_details()
#      86 self.grain_details()
# ---> 87 self.motor_details()
#
# File c:\Users\arthu\AppData\Local\Programs\Python\Python313\Lib\site-packages\rocketpy\prints\solid_motor_prints.py:69, in _SolidMotorPrints.motor_details(self)
#      65 print(
#      66     f"Total Propellant Mass: {self.solid_motor.propellant_initial_mass:.3f} kg"
#      67 )
#      68 print(f"Structural Mass Ratio: {self.solid_motor.structural_mass_ratio:.3f}")
# ---> 69 average = self.solid_motor.exhaust_velocity.average(*self.solid_motor.burn_time)
#      70 print(f"Average Propellant Exhaust Velocity: {average:.3f} m/s")
#      71 print(f"Average Thrust: {self.solid_motor.average_thrust:.3f} N")
#
# File c:\Users\arthu\AppData\Local\Programs\Python\Python313\Lib\site-packages\rocketpy\mathutils\function.py:3571, in funcify_method.<locals>.funcify_method_decorator.__get__(self, instance, owner)
#    3567 except KeyError:
#    3568     # If cache is not ready, create it
#    3569     try:
#    3570         # Handle methods which return Function instances
# -> 3571         val = self.func(instance).reset(*args, **kwargs)
#    3572     except AttributeError:
#    3573         # Handle methods which return a valid source
#    3574         source = self.func(instance)
#
# File c:\Users\arthu\AppData\Local\Programs\Python\Python313\Lib\site-packages\rocketpy\motors\solid_motor.py:385, in SolidMotor.exhaust_velocity(self)
#     373 @funcify_method("Time (s)", "Exhaust velocity (m/s)")
#     374 def exhaust_velocity(self):
#     375     """Exhaust velocity by assuming it as a constant. The formula used is
#     376     total impulse/propellant initial mass.
#     377
#    (...)
#     381         Gas exhaust velocity of the motor.
#     382     """
#     383     return Function(
#     384         self.total_impulse / self.propellant_initial_mass
# --> 385     ).set_discrete_based_on_model(self.thrust)
#
# File c:\Users\arthu\AppData\Local\Programs\Python\Python313\Lib\site-packages\rocketpy\mathutils\function.py:836, in Function.set_discrete_based_on_model(self, model_function, one_by_one, keep_self, mutate_self)
#     834     xs = model_function.source[:, 0]
#     835     ys = func.get_value(xs.tolist()) if one_by_one else func.get_value(xs)
# --> 836     func.set_source(np.concatenate(([xs], [ys])).transpose())
#     837 elif func.__dom_dim__ == 2:
#     838     # Create nodes to evaluate function
#     839     xs = model_function.source[:, 0]
#
# File c:\Users\arthu\AppData\Local\Programs\Python\Python313\Lib\site-packages\rocketpy\mathutils\function.py:264, in Function.set_source(self, source)
#     261         self.get_value_opt = self.__get_value_opt_nd
#     263 self.source = source
# --> 264 self.set_interpolation(self.__interpolation__)
#     265 self.set_extrapolation(self.__extrapolation__)
#     266 return self
#
# File c:\Users\arthu\AppData\Local\Programs\Python\Python313\Lib\site-packages\rocketpy\mathutils\function.py:309, in Function.set_interpolation(self, method)
#     307 if not callable(self.source):
#     308     self.__interpolation__ = self.__validate_interpolation(method)
# --> 309     self.__update_interpolation_coefficients(self.__interpolation__)
#     310     self.__set_interpolation_func()
#     311 return self
#
# File c:\Users\arthu\AppData\Local\Programs\Python\Python313\Lib\site-packages\rocketpy\mathutils\function.py:324, in Function.__update_interpolation_coefficients(self, method)
#     322     self._coeffs = self.__akima_coefficients__
#     323 elif method == "spline" or method is None:
# --> 324     self.__interpolate_spline__()
#     325     self._coeffs = self.__spline_coefficients__
#     326 else:
#
# File c:\Users\arthu\AppData\Local\Programs\Python\Python313\Lib\site-packages\rocketpy\mathutils\function.py:1907, in Function.__interpolate_spline__(self)
#    1905 vector_b.append(0)
#    1906 # Solve the system for c coefficients
# -> 1907 c = linalg.solve_banded(
#    1908     (1, 1), banded_matrix, vector_b, overwrite_ab=True, overwrite_b=True
#    1909 )
#    1910 # Calculate other coefficients
#    1911 b = (y[1:] - y[:-1]) / h - h * (2 * c[:-1] + c[1:]) / 3
#
# File c:\Users\arthu\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\linalg\_basic.py:441, in solve_banded(l_and_u, ab, b, overwrite_ab, overwrite_b, check_finite)
#     372 """
#     373 Solve the equation a x = b for x, assuming a is banded matrix.
#     374
#    (...)
#     437
#     438 """
#     440 a1 = _asarray_validated(ab, check_finite=check_finite, as_inexact=True)
# --> 441 b1 = _asarray_validated(b, check_finite=check_finite, as_inexact=True)
#     443 # Validate shapes.
#     444 if a1.shape[-1] != b1.shape[0]:
#
# File c:\Users\arthu\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\_lib\_util.py:321, in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     319         raise ValueError('masked arrays are not supported')
#     320 toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 321 a = toarray(a)
#     322 if not objects_ok:
#     323     if a.dtype is np.dtype('O'):
#
# File c:\Users\arthu\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:656, in asarray_chkfinite(a, dtype, order)
#     654 a = asarray(a, dtype=dtype, order=order)
#     655 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 656     raise ValueError(
#     657         "array must not contain infs or NaNs")
#     658 return a
#
# ValueError: array must not contain infs or NaNs

# %% [markdown]
# ## Rocket
# Currently, only single stage rockets are supported by Rocket-Serializer
# We will start by defining the aerodynamic surfaces, and then build the rocket.

# %% [markdown]
# ### Nosecones

# %%
nosecone = NoseCone(
    length=0.626872,
    kind="ogive",
    base_radius=0.078359,
    rocket_radius=0.078359,
    name="0.626872",
)

# %% [markdown]
# ### Fins
# As rocketpy allows for multiple fins sets, we will create a dictionary with all the fins sets and then add them to the rocket

# %%
trapezoidal_fins = {}

# %%
trapezoidal_fins[0] = TrapezoidalFins(
    n=3,
    root_chord=0.4064,
    tip_chord=0.13335,
    span=0.1651,
    cant_angle=0.0,
    sweep_length=0.2632814158417292,
    sweep_angle=None,
    rocket_radius=0.078359,
    name="Fin set",
)

# %% [markdown]
# ### Transitions (Tails)
# As rocketpy allows for multiple tails, we will create a dictionary with all the tails and then add them to the rocket

# %%
tails = {}

# %% [markdown]
# ### Parachutes
# As rocketpy allows for multiple parachutes, we will create a dictionary with all the parachutes and then add them to the rocket

# %%
parachutes = {}

# %%
parachutes[0] = Parachute(
    name="Iris Ultra Parachute [Cd 2.2 (10.9 oz) 60.0 in^3]",
    cd_s=4.013,
    trigger=304.800,
    sampling_rate=100,
)

# %%
parachutes[1] = Parachute(
    name='Parachute, nylon, conical, 30"',
    cd_s=0.456,
    trigger="apogee",
    sampling_rate=100,
)

# %%
rocket = Rocket(
    radius=0.078359,
    mass=15.497,
    inertia=[0.073, 0.073, 4.368],
    power_off_drag="drag_curve.csv",
    power_on_drag="drag_curve.csv",
    center_of_mass_without_motor=1.275,
    coordinate_system_orientation="nose_to_tail",
)

# %% [markdown]
# ### Adding surfaces to the rocket
# Now that we have all the surfaces, we can add them to the rocket

# %%
rocket.add_surfaces(
    surfaces=[nosecone, trapezoidal_fins[0]], positions=[0.0, 2.2461219999999984]
)

# %%
rocket.add_motor(motor, position=1.8078416409351568)

# %% [markdown]
# Adding parachutes to the rocket

# %%
rocket.parachutes = list(parachutes.values())

# %% [markdown]
# ### Rail Buttons

# %%
# No rail buttons were added to the rocket.

# %%
### Rocket Info
rocket.all_info()
# Out:
# Inertia Details
#
# Rocket Mass: 15.497 kg (without motor)
# Rocket Dry Mass: 15.497 kg (with unloaded motor)
# Rocket Loaded Mass: 17.764 kg
# Rocket Structural Mass Ratio: 0.872
# Rocket Inertia (with unloaded motor) 11: 0.073 kg*m2
# Rocket Inertia (with unloaded motor) 22: 0.073 kg*m2
# Rocket Inertia (with unloaded motor) 33: 4.368 kg*m2
# Rocket Inertia (with unloaded motor) 12: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 13: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 23: 0.000 kg*m2
#
# Geometrical Parameters
#
# Rocket Maximum Radius: 0.078359 m
# Rocket Frontal Area: 0.019290 m2
#
# Rocket Distances
# Rocket Center of Dry Mass - Center of Mass without Motor: 0.000 m
# Rocket Center of Dry Mass - Nozzle Exit: 0.883 m
# Rocket Center of Dry Mass - Center of Propellant Mass: 0.533 m
# Rocket Center of Mass - Rocket Loaded Center of Mass: 0.068 m
#
#
# Aerodynamics Lift Coefficient Derivatives
#
# 0.626872 Lift Coefficient Derivative: 2.000/rad
# Fin set Lift Coefficient Derivative: 7.780/rad
#
# Center of Pressure
#
# 0.626872 Center of Pressure position: 0.291 m
# Fin set Center of Pressure position: 2.429 m
#
# Stability
#
# Center of Mass position (time=0): 1.343 m
# Center of Pressure position (time=0): 1.992 m
# Initial Static Margin (mach=0, time=0): 4.139 c
# Final Static Margin (mach=0, time=burn_out): 4.573 c
# Rocket Center of Mass (time=0) - Center of Pressure (mach=0): 0.649 m
#
#
# Parachute Details
#
# Parachute Iris Ultra Parachute [Cd 2.2 (10.9 Oz) 60.0 In^3] with a cd_s of 4.0130 m2
# Ejection signal trigger: 304.8 m (AGL)
# Ejection system refresh rate: 100.000 Hz
# Time between ejection signal is triggered and the parachute is fully opened: 0.0 s
#
#
# Parachute Details
#
# Parachute Parachute, Nylon, Conical, 30" with a cd_s of 0.4560 m2
# Ejection signal trigger: At Apogee
# Ejection system refresh rate: 100.000 Hz
# Time between ejection signal is triggered and the parachute is fully opened: 0.0 s
#
#
# Rocket Draw
# ----------------------------------------
# Mass Plots
# ----------------------------------------
# Aerodynamics Plots
# ----------------------------------------
# Drag Plots
# --------------------
# Stability Plots
# --------------------
# Thrust-to-Weight Plot
# ----------------------------------------

# %% [markdown]
# ## Flight
# We will now create the flight simulation. Let's go!

# %%
flight = Flight(
    rocket=rocket,
    environment=env,
    rail_length=3.5,
    inclination=88.0,
    heading=90.0,
    terminate_on_apogee=False,
    max_time=600,
)

# %%
flight.all_info()
# Out:
# Initial Conditions
#
# Initial time: 0.000 s
# Position - x: 0.00 m | y: 0.00 m | z: 274.32 m
# Velocity - Vx: 0.00 m/s | Vy: 0.00 m/s | Vz: 0.00 m/s
# Attitude (quaternions) - e0: 0.707 | e1: -0.012 | e2: 0.012 | e3: -0.707
# Euler Angles - Spin φ : 0.00° | Nutation θ: -2.00° | Precession ψ: -90.00°
# Angular Velocity - ω1: 0.00 rad/s | ω2: 0.00 rad/s | ω3: 0.00 rad/s
# Initial Stability Margin: 4.139 c
#
#
# Surface Wind Conditions
#
# Frontal Surface Wind Speed: 0.00 m/s
# Lateral Surface Wind Speed: 0.00 m/s
#
#
# Launch Rail
#
# Launch Rail Length: 3.5 m
# Launch Rail Inclination: 88.00°
# Launch Rail Heading: 90.00°
#
#
# Rail Departure State
#
# Rail Departure Time: 0.281 s
# Rail Departure Velocity: 29.783 m/s
# Rail Departure Stability Margin: 4.180 c
# Rail Departure Angle of Attack: 0.000°
# Rail Departure Thrust-Weight Ratio: 13.840
# Rail Departure Reynolds Number: 3.128e+05
#
#
# Burn out State
#
# Burn out time: 2.764 s
# Altitude at burn out: 704.969 m (ASL) | 430.649 m (AGL)
# Rocket speed at burn out: 281.575 m/s
# Freestream velocity at burn out: 281.575 m/s
# Mach Number at burn out: 0.835
# Kinetic energy at burn out: 6.143e+05 J
#
#
# Apogee State
#
# Apogee Time: 22.376 s
# Apogee Altitude: 2921.014 m (ASL) | 2646.694 m (AGL)
# Apogee Freestream Speed: 6.888 m/s
# Apogee X position: 177.917 m
# Apogee Y position: 0.000 m
# Apogee latitude: 28.6100000°
# Apogee longitude: -80.5981795°
#
#
# Parachute Events
#
# Parachute: Parachute, Nylon, Conical, 30"
# 	Ejection time: 22.380 s
# 	Inflation time: 22.380 s
# 	Freestream speed at inflation: 6.888 m/s
# 	Altitude at inflation: 2921.014 m (ASL) | 2646.694 m (AGL)
# Parachute: Iris Ultra Parachute [Cd 2.2 (10.9 Oz) 60.0 In^3]
# 	Ejection time: 117.870 s
# 	Inflation time: 117.870 s
# 	Freestream speed at inflation: 24.050 m/s
# 	Altitude at inflation: 579.430 m (ASL) | 305.110 m (AGL)
#
#
# Impact Conditions
#
# Time of impact: 154.723 s
# X impact: 229.573 m
# Y impact: 0.000 m
# Altitude impact: 274.320 m (ASL) | -0.000 m (AGL)
# Latitude: 28.6100000°
# Longitude: -80.5976509°
# Vertical velocity at impact: -7.966 m/s
# Number of parachutes triggered until impact: 2
#
#
# Stability Margin
#
# Initial Stability Margin: 4.139 c at 0.00 s
# Out of Rail Stability Margin: 4.180 c at 0.28 s
# Maximum Stability Margin: 4.733 c at 2.77 s
# Minimum Stability Margin: 4.139 c at 0.00 s
#
#
# Maximum Values
#
# Maximum Speed: 282.788 m/s at 2.68 s
# Maximum Mach Number: 0.838 Mach at 2.69 s
# Maximum Reynolds Number: 2.878e+06 at 2.67 s
# Maximum Dynamic Pressure: 4.586e+04 Pa at 2.67 s
# Maximum Acceleration During Motor Burn: 133.757 m/s² at 0.08 s
# Maximum Gs During Motor Burn: 13.639 g at 0.08 s
# Maximum Acceleration After Motor Burn: 0.886 m/s² at 2.69 s
# Maximum Gs After Motor Burn: 0.090 Gs at 2.69 s
# Maximum Stability Margin: 4.733 c at 2.77 s
#
#
# Numerical Integration Settings
#
# Maximum Allowed Flight Time: 600.00 s
# Maximum Allowed Time Step: inf s
# Minimum Allowed Time Step: 0.00e+00 s
# Relative Error Tolerance: 1e-06
# Absolute Error Tolerance: [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 1e-06, 1e-06, 1e-06, 1e-06, 0.001, 0.001, 0.001]
# Allow Event Overshoot: True
# Terminate Simulation on Apogee: False
# Number of Time Steps Used: 895
# Number of Derivative Functions Evaluation: 133
# Average Function Evaluations per Time Step: 0.149
#
#
#
# Trajectory 3d Plot
# Trajectory Kinematic Plots
# Angular Position Plots
# Path, Attitude and Lateral Attitude Angle plots
# Trajectory Angular Velocity and Acceleration Plots
# Aerodynamic Forces Plots
# Rail Buttons Forces Plots
#
# No rail buttons were defined. Skipping rail button plots.
#
#
# Trajectory Energy Plots
# Trajectory Fluid Mechanics Plots
# Trajectory Stability and Control Plots
# Rocket and Parachute Pressure Plots
# Parachute:  Iris Ultra Parachute [Cd 2.2 (10.9 oz) 60.0 in^3]
# Parachute:  Parachute, nylon, conical, 30"

# %% [markdown]
# ## Compare Results
# We will now compare the results of the simulation with the parameters used to create it. Let's go!

# %%
### OpenRocket vs RocketPy Parameters
time_to_apogee_ork = 22.221
time_to_apogee_rpy = flight.apogee_time
print(f"Time to apogee (OpenRocket): {time_to_apogee_ork:.3f} s")
print(f"Time to apogee (RocketPy):   {time_to_apogee_rpy:.3f} s")
apogee_difference = time_to_apogee_rpy - time_to_apogee_ork
error = abs((apogee_difference) / time_to_apogee_rpy) * 100
print(f"Time to apogee difference:   {error:.3f} %")
print()

flight_time_ork = 142.81
flight_time_rpy = flight.t_final
print(f"Flight time (OpenRocket): {flight_time_ork:.3f} s")
print(f"Flight time (RocketPy):   {flight_time_rpy:.3f} s")
flight_time_difference = flight_time_rpy - flight_time_ork
error_flight_time = abs((flight_time_difference) / flight_time_rpy) * 100
print(f"Flight time difference:   {error_flight_time:.3f} %")
print()

ground_hit_velocity_ork = -7.622
ground_hit_velocity_rpy = flight.impact_velocity
print(f"Ground hit velocity (OpenRocket): {ground_hit_velocity_ork:.3f} m/s")
print(f"Ground hit velocity (RocketPy):   {ground_hit_velocity_rpy:.3f} m/s")
ground_hit_velocity_difference = ground_hit_velocity_rpy - ground_hit_velocity_ork
error_ground_hit_velocity = (
    abs((ground_hit_velocity_difference) / ground_hit_velocity_rpy) * 100
)
print(f"Ground hit velocity difference:   {error_ground_hit_velocity:.3f} %")
print()

launch_rod_velocity_ork = 30.286
launch_rod_velocity_rpy = flight.out_of_rail_velocity
print(f"Launch rod velocity (OpenRocket): {launch_rod_velocity_ork:.3f} m/s")
print(f"Launch rod velocity (RocketPy):   {launch_rod_velocity_rpy:.3f} m/s")
launch_rod_velocity_difference = launch_rod_velocity_rpy - launch_rod_velocity_ork
error_launch_rod_velocity = (
    abs((launch_rod_velocity_difference) / launch_rod_velocity_rpy) * 100
)
print(f"Launch rod velocity difference:   {error_launch_rod_velocity:.3f} %")
print()

max_acceleration_ork = 133.931
max_acceleration_rpy = flight.max_acceleration
print(f"Max acceleration (OpenRocket): {max_acceleration_ork:.3f} m/s²")
print(f"Max acceleration (RocketPy):   {max_acceleration_rpy:.3f} m/s²")
max_acceleration_difference = max_acceleration_rpy - max_acceleration_ork
error_max_acceleration = abs((max_acceleration_difference) / max_acceleration_rpy) * 100
print(f"Max acceleration difference:   {error_max_acceleration:.3f} %")
print()

max_altitude_ork = 2608.479
max_altitude_rpy = flight.apogee - flight.env.elevation
print(f"Max altitude (OpenRocket): {max_altitude_ork:.3f} m")
print(f"Max altitude (RocketPy):   {max_altitude_rpy:.3f} m")
max_altitude_difference = max_altitude_rpy - max_altitude_ork
error_max_altitude = abs((max_altitude_difference) / max_altitude_rpy) * 100
print(f"Max altitude difference:   {error_max_altitude:.3f} %")
print()

max_mach_ork = 0.833
max_mach_rpy = flight.max_mach_number
print(f"Max Mach (OpenRocket): {max_mach_ork:.3f}")
print(f"Max Mach (RocketPy):   {max_mach_rpy:.3f}")
max_mach_difference = max_mach_rpy - max_mach_ork
error_max_mach = abs((max_mach_difference) / max_mach_rpy) * 100
print(f"Max Mach difference:   {error_max_mach:.3f} %")
print()

max_velocity_ork = 280.996
max_velocity_rpy = flight.max_speed
print(f"Max velocity (OpenRocket): {max_velocity_ork:.3f} m/s")
print(f"Max velocity (RocketPy):   {max_velocity_rpy:.3f} m/s")
max_velocity_difference = max_velocity_rpy - max_velocity_ork
error_max_velocity = abs((max_velocity_difference) / max_velocity_rpy) * 100
print(f"Max velocity difference:   {error_max_velocity:.3f} %")
print()

max_thrust_ork = 2547.501
max_thrust_rpy = flight.rocket.motor.thrust.max
print(f"Max thrust (OpenRocket): {max_thrust_ork:.3f} N")
print(f"Max thrust (RocketPy):   {max_thrust_rpy:.3f} N")
max_thrust_difference = max_thrust_rpy - max_thrust_ork
error_max_thrust = abs((max_thrust_difference) / max_thrust_rpy) * 100
print(f"Max thrust difference:   {error_max_thrust:.3f} %")
print()

burnout_stability_margin_ork = 1.95
burnout_stability_margin_rpy = flight.stability_margin(
    flight.rocket.motor.burn_out_time
)
print(f"Burnout stability margin (OpenRocket): {burnout_stability_margin_ork:.3f}")
print(f"Burnout stability margin (RocketPy):   {burnout_stability_margin_rpy:.3f}")
burnout_stability_margin_difference = (
    burnout_stability_margin_rpy - burnout_stability_margin_ork
)
error_burnout_stability_margin = (
    abs((burnout_stability_margin_difference) / burnout_stability_margin_rpy) * 100
)
print(f"Burnout stability margin difference:   {error_burnout_stability_margin:.3f} %")
print()

max_stability_margin_ork = 2.165
max_stability_margin_rpy = flight.max_stability_margin
print(f"Max stability margin (OpenRocket): {max_stability_margin_ork:.3f}")
print(f"Max stability margin (RocketPy):   {max_stability_margin_rpy:.3f}")
max_stability_margin_difference = max_stability_margin_rpy - max_stability_margin_ork
error_max_stability_margin = (
    abs((max_stability_margin_difference) / max_stability_margin_rpy) * 100
)
print(f"Max stability margin difference:   {error_max_stability_margin:.3f} %")
print()

min_stability_margin_ork = 1.185
min_stability_margin_rpy = flight.min_stability_margin
print(f"Min stability margin (OpenRocket): {min_stability_margin_ork:.3f}")
print(f"Min stability margin (RocketPy):   {min_stability_margin_rpy:.3f}")
min_stability_margin_difference = min_stability_margin_rpy - min_stability_margin_ork
error_min_stability_margin = (
    abs((min_stability_margin_difference) / min_stability_margin_rpy) * 100
)
print(f"Min stability margin difference:   {error_min_stability_margin:.3f} %")
print()
# Out:
# Time to apogee (OpenRocket): 22.221 s
# Time to apogee (RocketPy):   22.376 s
# Time to apogee difference:   0.694 %
#
# Flight time (OpenRocket): 142.810 s
# Flight time (RocketPy):   154.723 s
# Flight time difference:   7.699 %
#
# Ground hit velocity (OpenRocket): -7.622 m/s
# Ground hit velocity (RocketPy):   -7.966 m/s
# Ground hit velocity difference:   4.320 %
#
# Launch rod velocity (OpenRocket): 30.286 m/s
# Launch rod velocity (RocketPy):   29.783 m/s
# Launch rod velocity difference:   1.689 %
#
# Max acceleration (OpenRocket): 133.931 m/s²
# Max acceleration (RocketPy):   133.757 m/s²
# Max acceleration difference:   0.130 %
#
# Max altitude (OpenRocket): 2608.479 m
# Max altitude (RocketPy):   2646.694 m
# Max altitude difference:   1.444 %
#
# Max Mach (OpenRocket): 0.833
# Max Mach (RocketPy):   0.838
# Max Mach difference:   0.586 %
#
# Max velocity (OpenRocket): 280.996 m/s
# Max velocity (RocketPy):   282.788 m/s
# Max velocity difference:   0.634 %
#
# Max thrust (OpenRocket): 2547.501 N
# Max thrust (RocketPy):   2547.501 N
# Max thrust difference:   0.000 %
#
# Burnout stability margin (OpenRocket): 1.950
# Burnout stability margin (RocketPy):   4.733
# Burnout stability margin difference:   58.798 %
#
# Max stability margin (OpenRocket): 2.165
# Max stability margin (RocketPy):   4.733
# Max stability margin difference:   54.256 %
#
# Min stability margin (OpenRocket): 1.185
# Min stability margin (RocketPy):   4.139
# Min stability margin difference:   71.368 %
